# %% [markdown]
# <a href="https://colab.research.google.com/github/greeshmakrishnan00/Machine-Learning/blob/main/Pakwheels_car_Regression_ML_(SVM_(svr)).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SVM-SVR**

# %% [markdown]
# # **REGRESSION**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/Pakwheels_car_data.csv")
df.head(5)
# Out:
#    Unnamed: 0                                Title  Model      Fuel    Engine  \
# 0           0          Audi e-tron  2021  for Sale   2021  Electric  95.0 kWh
# 1           1          Audi e-tron  2021  for Sale   2021  Electric  95.0 kWh
# 2           2  Lexus RX Series  2017 450H for Sale   2017    Petrol   3500 cc
# 3           3          Audi e-tron  2021  for Sale   2021  Electric  95.0 kWh
# 4           4  Lexus RX Series  2017 450H for Sale   2017    Petrol   3500 cc
#
#   Transmission_type Location           Price
# 0         Automatic   Lahore  PKR 2.65 crore
# 1         Automatic   Lahore  PKR 2.65 crore
# 2         Automatic   Lahore  PKR 2.32 crore
# 3         Automatic   Lahore  PKR 2.65 crore
# 4         Automatic   Lahore  PKR 2.32 crore

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20822 entries, 0 to 20821
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         20822 non-null  int64
#  1   Title              20822 non-null  object
#  2   Model              20822 non-null  int64
#  3   Fuel               20822 non-null  object
#  4   Engine             20822 non-null  object
#  5   Transmission_type  20822 non-null  object
#  6   Location           20822 non-null  object
#  7   Price              20822 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 1.3+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Title                0
# Model                0
# Fuel                 0
# Engine               0
# Transmission_type    0
# Location             0
# Price                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Visualization

# %%
plt.hist(df["Price"])
plt.show()

# %%
sns.histplot(df["Title"],kde=True)
plt.show()

# %% [markdown]
# # Correlation Analysis in EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20822 entries, 0 to 20821
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         20822 non-null  int64
#  1   Title              20822 non-null  object
#  2   Model              20822 non-null  int64
#  3   Fuel               20822 non-null  object
#  4   Engine             20822 non-null  object
#  5   Transmission_type  20822 non-null  object
#  6   Location           20822 non-null  object
#  7   Price              20822 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 1.3+ MB

# %%
print(df["Title"].unique())
# Out:
# ['Audi e-tron  2021  for Sale' 'Lexus RX Series  2017 450H for Sale'
#  'Mercedes Benz C Class  2008 C200 for Sale'
#  'Honda Vezel  2017 Hybrid RS Honda Sensing  for...'
#  'Toyota Vitz  2002 FL 1.0 for Sale'
#  'Suzuki Cultus  2016 EURO II for Sale'
#  'Mercedes Benz E Class  2018 E200 Exclusive for...'
#  'Mercedes Benz E Class Estate  2010 E 350 4MATI...'
#  'Mercedes Benz S Class  2004  for Sale'
#  'Changan Alsvin  2022 1.5L DCT Lumiere for Sale'
#  'Honda Civic  2022  for Sale' 'Honda BR-V  2018 i-VTEC S for Sale'
#  'Suzuki Wagon R  2011 Limited for Sale'
#  'Honda City  2012 1.3 i-VTEC for Sale'
#  'Suzuki Alto  2008 VXR (CNG) for Sale' 'Toyota Vitz  1999 F 1.0 for Sale'
#  'KIA Stonic  2022 EX+ for Sale'
#  'Honda Civic  2022 Oriel Prosmatec UG for Sale'
#  'Suzuki Wagon R  2017 FX Limited for Sale'
#  'Daihatsu Charade  1986 CX Turbo for Sale' 'Honda Civic  2018  for Sale'
#  'Honda City  2020 Aspire Prosmatec 1.5 i-VTEC f...'
#  'Honda Civic Eagle Eye 2005 VTi Oriel 1.6 for Sale'
#  'Honda Vezel  2014 Hybrid Z for Sale'
#  'Toyota Camry  2019 High Grade for Sale'
#  'Toyota Corolla  2015 GLi 1.3 VVTi for Sale'
#  'Suzuki Alto  2014 ECO-L for Sale' 'Toyota Vitz  2018 F 1.0 for Sale'
#  'Toyota Corolla  2015 Altis Grande CVT-i 1.8 fo...'
#  'Toyota Vitz  2019 F 1.0 for Sale'
#  'Toyota Corolla Fielder  2014 Hybrid G  WB  for...'
#  'Toyota Hilux  2020 Revo V Automatic 2.8 for Sale'
#  'Toyota Yaris  2021 ATIV X CVT 1.5 for Sale'
#  'Mercedes Benz E Class 4th (W212) Generation 20...'
#  'Toyota Surf  2000 SSR-G 3.4 for Sale'
#  'Mitsubishi Ek Wagon  2020 G Safety Plus Editio...'
#  'Daihatsu Cuore  2008 CX Eco for Sale'
#  'Honda City  2014 Aspire Prosmatec 1.3 i-VTEC f...'
#  'Toyota Corolla  2022 Altis X Automatic 1.6 Spe...'
#  'Toyota Corolla  2015 GLi Automatic 1.3 VVTi fo...'
#  'Honda BR-V  2020 i-VTEC S for Sale' 'Mitsubishi Rvr  2013  for Sale'
#  'Toyota Mark X  2004 250G for Sale' 'Suzuki Cultus  2004 VXR for Sale'
#  'Honda Cross Road  2008 1.8 L X PACKAGE for Sale'
#  'Daihatsu Mira  2008 Custom RS for Sale'
#  'Honda Civic Reborn 2011 VTi Oriel Prosmatec 1....'
#  'Honda Civic  2021 Oriel 1.8 i-VTEC CVT for Sale'
#  'KIA Sportage  2021 FWD for Sale' 'Suzuki Wagon R  2017 VXL for Sale'
#  'Honda City  2009 1.3 i-VTEC for Sale' 'Suzuki Baleno  2002  for Sale'
#  'Toyota Land Cruiser  1987 RKR for Sale' 'Suzuki Alto  2004 VXR for Sale'
#  'United Bravo  2022  for Sale' 'Daihatsu Mira  2019  for Sale'
#  'Suzuki Bolan  2016 VX Euro II for Sale'
#  'Suzuki Wagon R  2007 Limited for Sale' 'Suzuki Alto  2001 VXR for Sale'
#  'Honda Civic Reborn 2010 VTi Oriel Prosmatec 1....'
#  'Honda Civic EK 1998 VTi Automatic 1.6 for Sale'
#  'Mitsubishi Minica  2006  for Sale'
#  'Toyota Hilux  2018 Revo V Automatic 2.8 for Sale'
#  'Mercedes Benz C Class  2016 C180 Exclusive for...'
#  'Suzuki Swift  2018 DLX 1.3 Navigation  for Sale'
#  'BMW 3 Series  2015 316i for Sale'
#  'Toyota Prado 120 Series 2003 TZ G 3.4 for Sale'
#  'Toyota Land Cruiser  2015 ZX for Sale'
#  'Toyota Corolla Axio  2007 G for Sale'
#  'Honda Vezel  2017 Hybrid Z Honda Sensing  for ...'
#  'Daihatsu Mira  2014 ES for Sale'
#  'Toyota Corolla Fielder  2019 Hybrid G for Sale'
#  'Toyota Land Cruiser  2013 ZX for Sale'
#  'Honda Civic  2017 Oriel 1.8 i-VTEC CVT for Sale'
#  'Toyota Corolla  2016 GLi Automatic 1.3 VVTi fo...'
#  'Suzuki Cultus  2010 VXRi (CNG) for Sale'
#  'Honda Civic  2001 VTi Oriel Automatic 1.6 for ...'
#  'Suzuki Mehran  2006 VX (CNG) for Sale'
#  'Suzuki Wagon R  2007 FX Limited for Sale'
#  'Toyota Corolla  1986  for Sale'
#  'Toyota Corolla 9th Generation 2007 XLi for Sale'
#  'Suzuki Khyber  1996  for Sale' 'Toyota Vitz  2007 B 1.0 for Sale'
#  'Toyota Passo  2015 + Hana 1.0 for Sale'
#  'Honda City  2019 1.3 i-VTEC Prosmatec for Sale'
#  'Toyota Vitz  2007 F 1.0 for Sale' 'Suzuki Cultus  2015 EURO II for Sale'
#  'Toyota Fortuner  2022 2.7 V for Sale'
#  'Toyota Corolla  2012 XLi VVTi for Sale'
#  'Toyota Passo  2007 G 1.0 for Sale'
#  'Suzuki Cultus  2011 EURO II for Sale'
#  'Toyota Corolla  2012 GLi 1.3 VVTi for Sale'
#  'Suzuki Cultus  2007 VX (CNG) for Sale'
#  'Audi A6 4th (C7) Generation 2017 1.8 TFSI  for...'
#  'BMW 7 Series 5th (F01) Generation 2014 ActiveH...'
#  'Toyota Corolla 9th Generation 2007 Altis Autom...'
#  'Toyota Passo  2019 X L Package S  for Sale'
#  'Toyota Aqua  2018 S for Sale' 'Toyota Land Cruiser  2016 ZX for Sale'
#  'Toyota Prado 120 Series 2006 TZ G 4.0 for Sale'
#  'Audi A5  2019 1.4 TFSI Sportback for Sale'
#  'BAIC BJ40 Plus  2022 Honorable Edition for Sale'
#  'MG HS  2021 1.5 Turbo for Sale'
#  'Toyota Corolla 9th Generation 2006 XLi for Sale'
#  'Honda City  2017 1.3 i-VTEC for Sale' 'Toyota Aqua  2015 S for Sale'
#  'Mazda 1300  1982  for Sale' 'Toyota Prado  2010 TX 2.7 for Sale'
#  'Honda Civic  2020 Oriel 1.8 i-VTEC CVT for Sale'
#  'Suzuki Swift  2021 DLX 1.3 Navigation  for Sale'
#  'Toyota Belta  2007 X L Package 1.3 for Sale' 'BMW i8  2015  for Sale'
#  'Toyota Vitz  2018 F M Package 1.0 for Sale'
#  'Honda City  2016 1.3 i-VTEC for Sale'
#  'Toyota Corolla  2011 Altis SR Cruisetronic 1.8...'
#  'Toyota Vitz  2014 F Intelligent Package 1.0 fo...'
#  'Suzuki Every  2017 PC for Sale' 'Suzuki Wagon R  2022 AGS for Sale'
#  'Suzuki Wagon R  2022 VXL for Sale'
#  'Toyota Corolla  2021 Altis Automatic 1.6 for Sale'
#  'Toyota Corolla  2018 GLi Automatic 1.3 VVTi fo...'
#  'Lexus LX Series  2017 LX570 for Sale'
#  'Toyota Land Cruiser  2012 ZX 60th Black Leathe...'
#  'Toyota Yaris  2020 ATIV X CVT 1.5 for Sale'
#  'Toyota Mark II  2004 Grande 2.5 for Sale'
#  'Toyota Aqua  2019 G LED Soft Leather Selection...'
#  'Toyota Crown  2018  for Sale' 'Honda City  2005 i-DSI for Sale'
#  'KIA Sportage  2021 AWD for Sale' 'Nissan Note  2019 MEDALIST for Sale'
#  'Honda Civic  2018 Oriel 1.8 i-VTEC CVT for Sale'
#  'Daihatsu Hijet  2012 Deluxe for Sale'
#  'Toyota Coaster  2013 29 Seater F/L for Sale'
#  'Toyota Prado  2016 TX 2.7 for Sale'
#  'Mercedes Benz E Class 3rd (W211) Generation 20...'
#  'Suzuki Cultus  2002 VXR for Sale' 'Daihatsu Tanto  2011  for Sale'
#  'Honda Civic  2022 VTi 1.8 i-VTEC for Sale'
#  'Nissan AD Van  2007 1.3 DX for Sale'
#  'Suzuki Alto  2015 TURBO RS for Sale'
#  'Suzuki Cultus  2009 VXLi (CNG) for Sale'
#  'Toyota Rush  2007 X Smart Edition for Sale'
#  'Toyota Land Cruiser 80 Series 1995 VX 4.2D for...'
#  'Toyota Corolla  2011 GLi Limited Edition 1.3 V...'
#  'Toyota Land Cruiser  2019 ZX for Sale'
#  'Toyota Land Cruiser  2007 Cygnus for Sale' 'Honda Fit  2012  for Sale'
#  'Honda City  2015 1.3 i-VTEC Prosmatec for Sale'
#  'Toyota Vitz  2015 F 1.0 for Sale' 'Nissan Dayz  2018 J for Sale'
#  'Toyota Land Cruiser  2016 AX for Sale'
#  'Honda Civic Reborn 2010 VTi 1.8 i-VTEC for Sale'
#  'Toyota Premio  2010 F L Package Prime Selectio...'
#  'Suzuki Swift  2022 XL 1.2 for Sale'
#  'Suzuki Mehran  2016 VX Euro II for Sale'
#  'Suzuki Cultus  2016 Limited Edition for Sale'
#  'Suzuki Alto  2012 VXR (CNG) for Sale'
#  'Honda Civic Rebirth 2014 VTi Oriel Prosmatec 1...'
#  'Honda Civic  2019 Oriel 1.8 i-VTEC CVT for Sale'
#  'Toyota Corolla  2012 GLi Automatic 1.6 VVTi fo...'
#  'Toyota Corolla  2011 GLi 1.3 VVTi for Sale'
#  'Jaguar Other  2005  for Sale' 'Toyota Corolla  1994  for Sale'
#  'Toyota Corolla  2017 Altis Grande CVT-i 1.8 fo...'
#  'Suzuki Alto  2014 ECO-S for Sale'
#  'Toyota Premio  2003 G EX Package 2.0 for Sale'
#  'Suzuki Alto  2022 VXR for Sale' 'Toyota Surf  2001 SSR-G 3.4 for Sale'
#  'Toyota Prado 120 Series 2003 TZ 3.4 for Sale'
#  'Toyota Mark II  1995  for Sale'
#  'Suzuki Mehran  2016 VXR Euro II (CNG) for Sale'
#  'Suzuki Baleno  2005 JXL for Sale' 'Suzuki Alto  2022 VX for Sale'
#  'Toyota Fortuner  2022 2.8 Sigma 4 for Sale'
#  'Honda Vezel  2016 Hybrid Z Honda Sensing  for ...'
#  'Suzuki Alto  2020 VXR for Sale' 'Suzuki Mehran  2012 VX for Sale'
#  'Toyota Hilux  2021 Revo V Automatic 2.8 for Sale'
#  'Toyota Voxy  2016 ZS KIRAMEKI II for Sale'
#  'Honda Civic Reborn 2007 VTi 1.8 i-VTEC for Sale'
#  'Toyota Raize  2019 Z for Sale' 'Suzuki Ciaz  2017 Automatic for Sale'
#  'Suzuki Liana  2010 Eminent Automatic for Sale'
#  'Daihatsu Move  2012 X for Sale' 'Daihatsu Mira  2018 X for Sale'
#  'Toyota Crown  2018 RS Advance for Sale'
#  'Honda Insight  2019 HDD Navi Special Edition f...'
#  'Suzuki Alto  2021 VXL AGS for Sale' 'Suzuki Mehran  2006 VXR for Sale'
#  'Toyota Prado  2016 TX L Package 2.7 for Sale'
#  'Suzuki Mehran  2010 VX for Sale'
#  'Toyota Corolla  2009 2.0D Saloon for Sale'
#  'Daihatsu Hijet  2016 Deluxe for Sale'
#  'Mitsubishi Lancer  2005 GLX 1.5 for Sale'
#  'Honda CR-Z Sports Hybrid  2010 Alpha Master La...'
#  'Toyota Hilux  1998 Double Cab for Sale'
#  'Suzuki Khyber  1992 GA for Sale' 'Suzuki Cultus  2007 VXR for Sale'
#  'Toyota Vitz  2006 F 1.0 for Sale'
#  'Toyota Corolla  2018 Altis Grande CVT-i 1.8 fo...'
#  'Toyota Corolla  2017 GLi 1.3 VVTi for Sale'
#  'Suzuki Mehran  2013 VXR Euro II for Sale'
#  'Honda City  2005 i-DSI Vario for Sale' 'MG HS  2021  for Sale'
#  'Honda N Wgn  2014 Custom G L Package for Sale'
#  'Suzuki Wagon R  2021 VXL for Sale' 'Toyota Passo  2018 X for Sale'
#  'Toyota Passo  2018 Moda for Sale' 'Toyota Mark X  2006 250G for Sale'
#  'DFSK Glory 580  2020 1.8 CVT for Sale' 'Toyota Tacoma  2017  for Sale'
#  'Dodge Challenger  2011  for Sale' 'Toyota Passo  2018 X S  for Sale'
#  'KIA Sportage  2022 AWD for Sale'
#  'Toyota Corolla  2022 Altis Grande X CVT-i 1.8 ...'
#  'Mercedes Benz E Class  2021 E 180 Exclusive fo...'
#  'Suzuki Swift  2022 GLX CVT for Sale'
#  'Toyota Hilux  2013 4x4 Double Cab Standard for...'
#  'Nissan Roox  2013 HIGHWAY STAR TURBO URBAN SEL...'
#  'Suzuki Alto  2011 VXR for Sale'
#  'Toyota Corolla  2022 GLi Special Edition 1.6 f...'
#  'Toyota Prado  1989  for Sale' 'Suzuki Mehran  2012 VXR for Sale'
#  'Datsun 120 Y  1982  for Sale' 'Suzuki Mehran  2016 VXR Euro II for Sale'
#  'Honda Civic EG 1995  for Sale' 'Toyota Camry XV50 2014 Hybrid for Sale'
#  'Suzuki Alto  2005 VXR (CNG) for Sale'
#  'Honda Civic Eagle Eye 2005 VTi Oriel Prosmatec...'
#  'Suzuki Cultus  2010 VXRi for Sale' 'Toyota Fortuner  2021  for Sale'
#  'Honda City  2010 1.3 i-VTEC for Sale'
#  'Toyota Corolla  2012 GLi Limited Edition 1.3 V...'
#  'Honda City  2013 Aspire Prosmatec 1.3 i-VTEC f...'
#  'Mercedes Benz C Class  2018 C180 Exclusive for...'
#  'Mercedes Benz C Class  2018 C180 Avantgarde fo...'
#  'Honda Civic  2022 1.5 VTEC Turbo Oriel for Sale'
#  'Toyota Allion  2007 A15 for Sale' 'Toyota Passo  2019 X for Sale'
#  'Honda City  2011 1.3 i-VTEC for Sale' 'Toyota Vitz  2012 F 1.0 for Sale'
#  'Toyota Hilux  2017 Revo V Automatic 3.0  for Sale'
#  'DFSK Glory 580  2021 Pro for Sale' 'Suzuki Mehran  2017  for Sale'
#  'Daihatsu Boon  2018 1.0 CL Limited for Sale'
#  'Suzuki Mehran  2015 VX Euro II for Sale' 'Toyota Aqua  2017 S for Sale'
#  'Toyota Corolla  2016 Altis Grande 1.8 for Sale'
#  'Mitsubishi I Mivec  2014  for Sale'
#  'Toyota Prado 120 Series 2007 TZ 3.0D for Sale'
#  'Honda City  2018 Aspire Prosmatec 1.5 i-VTEC f...'
#  'Suzuki Swift  2010 DLX 1.3 Navigation  for Sale'
#  'KIA Other  2021  for Sale' 'Honda BR-V  2019 i-VTEC S for Sale'
#  'Toyota Crown  2019 Royal Saloon G for Sale'
#  'Suzuki Alto  2020 VXL AGS for Sale'
#  'Toyota Land Cruiser  1998 VX Limited 4.7 for Sale'
#  'Nissan Moco  2007 E Chocolatier Selection for ...'
#  'Toyota Camry XV40 2006 G for Sale'
#  'Toyota Passo  2010 + Hana 1.0 for Sale'
#  'Toyota Hilux  2022 Revo V Automatic 2.8 for Sale'
#  'Mercedes Benz C Class  2012 C250 CDI 4MATIC fo...'
#  'Honda Civic  2022 Oriel 1.8 i-VTEC CVT for Sale'
#  'Toyota Fortuner  2021 2.8 Sigma 4 for Sale'
#  'Honda City  2022 1.5L ASPIRE CVT for Sale'
#  'Honda City  2017 1.3 i-VTEC Prosmatec for Sale'
#  'Honda Civic Rebirth 2013 Oriel Prosmatec UG fo...'
#  'Toyota Land Cruiser  2008 AX G Selection for Sale'
#  'Suzuki Potohar  2006 Basegrade for Sale'
#  'Suzuki Mehran  2017 VX Euro II for Sale'
#  'Hyundai Santro  2005 Club for Sale'
#  'Suzuki Mehran  2012 VX Euro II for Sale'
#  'Toyota Corolla  2011 Altis 1.6 for Sale'
#  'Toyota Corolla  2014 XLi VVTi for Sale'
#  'Honda City  2022 Aspire Prosmatec 1.5 i-VTEC f...'
#  'Suzuki Alto  2019 VXL AGS for Sale'
#  'Honda Civic  2001 VTi Oriel Prosmatec 1.6 for ...'
#  'Honda Insight  2019  for Sale'
#  'Toyota Corolla  2019 Altis X Automatic 1.6 Spe...'
#  'Toyota Corolla Axio  2013  for Sale'
#  'Honda Vezel  2015 Hybrid Z Honda Sensing  for ...'
#  'Nissan Dayz  2019 S for Sale' 'Toyota Hilux  2012 SR5(4x4) for Sale'
#  'Toyota Passo  2015 X G Package for Sale' 'MG ZS  2021  for Sale'
#  'Nissan Dayz Highway Star  2017  for Sale'
#  'Suzuki Cultus  2021 Auto Gear Shift for Sale'
#  'Honda Civic Reborn 2011 VTi Oriel 1.8 i-VTEC f...'
#  'Hyundai Santro  2006 Exec GV for Sale'
#  'Honda City  2022 1.2L CVT for Sale'
#  'Toyota Mark X  2005 250G F Package Smart Editi...'
#  'Nissan AD Van  2006 1.5 DX for Sale' 'Nissan Dayz  2013  for Sale'
#  'Honda Civic  2016 Oriel 1.8 i-VTEC CVT for Sale'
#  'Daihatsu Cuore  2010  for Sale'
#  'Honda Civic Rebirth 2013 VTi 1.8 i-VTEC for Sale'
#  'Toyota Corolla  2019 XLi Automatic for Sale'
#  'Suzuki Alto  2012 VXR for Sale'
#  'Toyota Prado  2018 TX L Package 2.7 for Sale'
#  'Daihatsu Move  2018 X for Sale'
#  'Toyota Passo  2016 X L Package for Sale'
#  'Toyota Corolla  2018 Altis Grande X CVT-i 1.8 ...'
#  'Honda Civic  2002 EXi Prosmatec for Sale'
#  'Suzuki Swift  2007 XG 1.3 for Sale' 'Daihatsu Move  2014  for Sale'
#  'Honda Civic  2012 VTi Oriel 1.8 i-VTEC for Sale'
#  'Toyota Land Cruiser  2009 AX G Selection for Sale'
#  'Mercedes Benz C Class  2011 C200 for Sale'
#  'Honda Vezel  2015 Hybrid Z Style Edition for Sale'
#  'MG HS  2022 1.5 Turbo for Sale'
#  'Toyota Prius Alpha  2017 S L Selection for Sale'
#  'Toyota C-HR  2017  for Sale' 'Toyota Aqua  2018 G for Sale'
#  'Toyota Passo  2018 X L Package S  for Sale'
#  'Suzuki Alto  2021  for Sale' 'Honda Civic  2006 EXi for Sale'
#  'Honda Fit  2019 1.5 Hybrid S Package for Sale'
#  'Toyota Vitz  2016 F 1.0 for Sale' 'Daihatsu Mira  2021 L for Sale'
#  'Toyota Yaris  2022 ATIV X CVT 1.5 for Sale'
#  'Honda City  2014 1.3 i-VTEC for Sale'
#  'Honda Civic  2016 Turbo 1.5 VTEC CVT for Sale'
#  'Toyota Town Ace  2010  for Sale' 'Suzuki Cultus  2013 EURO II for Sale'
#  'Toyota Passo  2018 X L Package for Sale'
#  'Mitsubishi Ek Wagon  2018 E for Sale'
#  'Toyota Land Cruiser 100 Series 2005 Cygnus for...'
#  'Toyota Prius  2013 S LED Edition 1.8 for Sale'
#  'Toyota Corolla  2017 Altis Automatic 1.6 for Sale'
#  'Toyota Prado 90 Series 1996 RZ 3.0D (3-Door) f...'
#  'Toyota Corolla  2022 Altis Automatic 1.6 for Sale'
#  'Toyota Corolla  2011 Altis Cruisetronic 1.6 fo...'
#  'KIA Picanto  2021 1.0 AT for Sale'
#  'Range Rover Sport  2007 Supercharged 4.2 V8 fo...'
#  'Honda Civic Hybrid  2006 MXB for Sale'
#  'Toyota Vitz  2008 B 1.0 for Sale' 'Toyota C-HR  2016 S 1.8 for Sale'
#  'BMW i8  2018 Roadster for Sale'
#  'Honda Civic  2003 EXi Prosmatec for Sale'
#  'Toyota Corolla  2009 Altis SR Cruisetronic 1.8...'
#  'Suzuki Mehran  2009 VXR for Sale'
#  'Honda Civic Eagle Eye 2005 EXi for Sale'
#  'Daihatsu Cuore  2011 CX Ecomatic for Sale' 'Toyota Will  2003  for Sale'
#  'Suzuki Wagon R  2019 VXR for Sale' 'Daihatsu Move  2019 L for Sale'
#  'Toyota Corolla Indus 1998  for Sale'
#  'Honda Civic Reborn 2007 VTi Prosmatec 1.8 i-VT...'
#  'Toyota Corolla  2019 GLi 1.3 VVTi for Sale'
#  'Toyota Prado  2017 TX 2.7 for Sale'
#  'Toyota Yaris  2020 ATIV MT 1.3 for Sale'
#  'Honda BR-V  2017 i-VTEC S for Sale'
#  'Suzuki Mehran  2011 VX (CNG) for Sale'
#  'Toyota Vitz  2019 F Limited 1.0 for Sale'
#  'Toyota Land Cruiser  2017 ZX for Sale' 'Nissan Pino  2007 S for Sale'
#  'Suzuki Jimny Sierra  2018 LAND VENTURE for Sale'
#  'Honda Civic Reborn 2009 VTi Oriel Prosmatec 1....'
#  'Toyota Corolla  2022 Altis X Automatic 1.6 for...'
#  'Suzuki Alto Lapin  2016 Turbo for Sale'
#  'Suzuki Mehran  1992 VX for Sale' 'Suzuki Swift  2022 XS 1.2 for Sale'
#  'Suzuki Cultus  2009 VXRi (CNG) for Sale'
#  'Toyota Corolla  2010 XLi VVTi for Sale'
#  'Honda Grace Hybrid 6th Generation 2016 DX for ...'
#  'Toyota Corolla  2003 SE Saloon Automatic for Sale'
#  'Toyota Prado  1991 RZ 3.0D (3-Door) for Sale'
#  'Audi A4 4th (B8) Generation 2011 1.8 TFSI for ...'
#  'Toyota Corolla  2010 GLi 1.3 VVTi for Sale'
#  'Honda Grace Hybrid 6th Generation 2015 EX for ...'
#  'Toyota Aqua  2017  for Sale' 'Suzuki Swift  2015 DLX 1.3 for Sale'
#  'Toyota Vitz  2006 U 1.0 for Sale'
#  'Mercedes Benz S Class  1992 300SEL for Sale'
#  'Hyundai Tucson  2021 AWD A/T Ultimate for Sale'
#  'Honda City  2006 VTEC Steermatic for Sale'
#  'Toyota Prius Alpha  2012 G Touring for Sale'
#  'Toyota Corolla  2013 GLi 1.3 VVTi for Sale'
#  'Toyota Vitz  2018 F Smile Edition 1.0 for Sale'
#  'Honda Civic  2022 Oriel for Sale' 'Honda N Box  2015 G for Sale'
#  'Suzuki Alto  2010 VXR (CNG) for Sale'
#  'Suzuki Cultus  2006 VXR (CNG) for Sale'
#  'Honda Civic  2006 VTi Oriel Prosmatec 1.6 for ...'
#  'Toyota Premio  2009 F 1.5 for Sale'
#  'Suzuki Cultus  2008 Euro II (CNG) for Sale'
#  'Toyota Prius  2011 L 1.8 for Sale'
#  'Daihatsu Hijet  2014 Deluxe for Sale'
#  'Honda Civic Reborn 2009  for Sale'
#  'Toyota Corolla  2009 GLi 1.3 VVTi for Sale'
#  'Toyota Vitz  2014 F 1.0 for Sale' 'Suzuki Swift  2019 RS 1.0 for Sale'
#  'Toyota Corolla  2018 XLi VVTi for Sale'
#  'Suzuki Mehran  2019 VXR Euro II for Sale'
#  'Suzuki Mehran  1996 VXR for Sale' 'Daihatsu Cuore  2004 CX for Sale'
#  'Honda Civic Rebirth 2013 VTi Oriel Prosmatec 1...'
#  'Toyota Prado 90 Series 1997 TX 3.0D for Sale'
#  'Toyota Aqua  2016 G LED Soft Leather Selection...'
#  'Toyota Corolla  2018 GLi 1.3 VVTi for Sale'
#  'Toyota Corolla  2018 Altis Automatic 1.6 for Sale'
#  'Toyota Pixis Epoch  2016 L for Sale'
#  'Daihatsu Mira  2014 Custom X for Sale'
#  'Audi e-tron  2022 50 Quattro 230 kW for Sale'
#  'Toyota Corolla  2020  for Sale'
#  'Proton Saga  2022 1.3L Ace A/T for Sale'
#  'Suzuki Swift  2013 DLX Automatic 1.3 for Sale'
#  'Toyota Corolla  1995 LX Limited 1.5 for Sale'
#  'Suzuki Carry  1996 Standard for Sale' 'Suzuki Mehran  1998 VX for Sale'
#  'Suzuki Cultus  2009 VXRi for Sale' 'Honda N One  2016 G for Sale'
#  'Suzuki Mehran  2010 VXR (CNG) for Sale'
#  'Toyota Fortuner  2018 2.8 Sigma 4 for Sale' 'Honda City  2004  for Sale'
#  'Suzuki Wagon R  2018 VXL for Sale' 'Suzuki Alto  2000 VXR for Sale'
#  'Isuzu D-Max  2019  for Sale' 'Suzuki Mehran  2007 VXR for Sale'
#  'Toyota Surf  1996 SSR-X 3.0D for Sale'
#  'Toyota Prius  2011 G LED Edition 1.8 for Sale'
#  'Toyota Corolla Axio  2018 X 1.5 for Sale'
#  'Honda Civic Reborn 2009 VTi Oriel 1.8 i-VTEC f...'
#  'Changan Alsvin  2021 1.5L DCT Lumiere for Sale'
#  'Toyota Surf  2004 SSR-X 2.7 for Sale'
#  'Audi e-tron  2020 50 Quattro 230 kW for Sale'
#  'Toyota Land Cruiser  2009 AX for Sale'
#  'Hyundai Sonata  2021 2.5 for Sale' 'Hyundai Sonata  2022  for Sale'
#  'Adam Revo  2017  for Sale'
#  'Toyota Corolla  2013 GLi Automatic 1.6 VVTi fo...'
#  'Daihatsu Mira  2012 ES for Sale' 'Toyota Prius  2011 S 1.8 for Sale'
#  'Suzuki Alto  2022 VXL AGS for Sale'
#  'Toyota Hilux  2015 Vigo Champ GX for Sale'
#  'Suzuki Alto  2017 L for Sale'
#  'Toyota Land Cruiser 100 Series 2003  for Sale'
#  'Toyota Prado 90 Series 2001 TZ 3.4 for Sale'
#  'Daihatsu Cuore  2008 CL Eco for Sale'
#  'Honda Civic  2012 VTi Oriel Prosmatec 1.8 i-VT...'
#  'Toyota Corolla  2013 XLi VVTi for Sale'
#  'Toyota Fortuner  2018 2.7 VVTi for Sale'
#  'Honda Civic  2004 EXi Prosmatec for Sale'
#  'Suzuki Bolan  2015 VX Euro II for Sale' 'Prince Pearl  2020 MT for Sale'
#  'Honda Vezel  2016 Hybrid Z for Sale'
#  'Honda Vezel  2016 Hybrid RS Honda Sensing  for...'
#  'Suzuki Alto  2018 L for Sale'
#  'Toyota Prado 120 Series 2009 TX L Package 2.7 ...'
#  'Daihatsu Boon  2019 1.0 CL Limited for Sale'
#  'Toyota Yaris  2020 GLI CVT 1.3 for Sale'
#  'Toyota Corolla  2014 Altis Grande CVT-i 1.8 fo...'
#  'Toyota Hilux  2018 Revo G Automatic 2.8 for Sale'
#  'Toyota Sai  2012  for Sale' 'Toyota Hilux  2012 Vigo Champ G for Sale'
#  'Toyota Corolla  1995 SE Limited for Sale' 'Honda Civic  1996  for Sale'
#  'Toyota Yaris  2021 ATIV CVT 1.3 for Sale'
#  'Mitsubishi Minica  2007 PC for Sale'
#  'Suzuki Mehran  2018 VXR Euro II for Sale'
#  'Toyota Prado 90 Series 2001 TZ 3.0D for Sale'
#  'Suzuki Other  2001  for Sale'
#  'Mitsubishi Pajero  1999 Exceed 3.5 for Sale'
#  'Toyota Prado 120 Series 2009 TX 2.7 for Sale'
#  'Suzuki Swift  2017 RS 1.0 for Sale'
#  'Mercedes Benz C Class  2015 C180 for Sale'
#  'Toyota Land Cruiser 80 Series 1993 VX 4.5 for ...'
#  'Toyota Land Cruiser  2012 AX for Sale'
#  'Toyota Prius  2018 PHV (Plug In Hybrid) for Sale'
#  'Suzuki Cultus  2019 VXR for Sale'
#  'Toyota Hilux  2019 Revo V Automatic 2.8 for Sale'
#  'Suzuki Mehran  1990 VXR for Sale' 'Toyota Premio  2007 X 1.8 for Sale'
#  'Honda City  2000 EXi S for Sale' 'Suzuki Swift  2022  for Sale'
#  'Toyota Passo  2011 + Hana 1.0 for Sale'
#  'Honda City  2021 1.2L CVT for Sale'
#  'Toyota Corolla  2008 GLi 1.3 for Sale'
#  'Nissan Qashqai  2011 SL for Sale'
#  'Toyota Corolla  2015 Altis Automatic 1.6 for Sale'
#  'Suzuki Alto  2021 VX for Sale' 'Suzuki Cultus  2007 VXR (CNG) for Sale'
#  'Suzuki Jimny  2016 XC for Sale' 'Toyota Surf  1997 SSR-X 2.7 for Sale'
#  'Suzuki Mehran  2019 VX Euro II for Sale'
#  'Mercedes Benz C Class  2019 C200 for Sale'
#  'Daihatsu Hijet  2013 Cruise for Sale'
#  'Bentley Continental Gt  2007  for Sale'
#  'Honda City  2012 1.3 i-VTEC Prosmatec for Sale'
#  'Toyota Corolla  2019 Altis Automatic 1.6 for Sale'
#  'Suzuki Liana  2006 LXi for Sale'
#  'Toyota Fortuner  2013 2.7 VVTi for Sale'
#  'Toyota Corolla  2016 Altis Grande CVT-i 1.8 fo...'
#  'Isuzu D-Max  2021 V-Cross Automatic 3.0 for Sale'
#  'Toyota Corolla  2004 XLi for Sale'
#  'Toyota Corolla Fielder  2007 X for Sale'
#  'Honda Vezel  2015 Hybrid Z for Sale' 'Suzuki Mehran  2010 VXR for Sale'
#  'Toyota Corolla  2021  for Sale' 'Suzuki Baleno  2005 JXR for Sale'
#  'Toyota Land Cruiser 100 Series 2002 VX Limited...'
#  'Suzuki Swift  2022 XG 1.2 for Sale' 'Mitsubishi Pajero  2000  for Sale'
#  'Suzuki Ravi  2020 Euro II for Sale' 'Suzuki Ravi  2022 Euro II for Sale'
#  'Toyota Corolla  2011 XLi VVTi for Sale' 'Suzuki Alto  2020 X for Sale'
#  'Toyota Fortuner  2019 2.7 VVTi for Sale'
#  'Mitsubishi Pajero Mini  1998 XR for Sale'
#  'Toyota Corolla  2011 Altis SR Cruisetronic 1.6...'
#  'Suzuki Cultus  2006 VXR for Sale' 'KIA Picanto  2022 1.0 AT for Sale'
#  'Honda Civic Rebirth 2013 VTi Prosmatec 1.8 i-V...'
#  'Adam Revo  2021  for Sale' 'Suzuki Swift  2018 DLX 1.3 for Sale'
#  'Suzuki Jimny  2014 JLDX for Sale'
#  'Toyota Yaris  2021 GLI MT 1.3 for Sale'
#  'Toyota Corolla  2016 XLi Automatic for Sale'
#  'Suzuki Cultus  2015 VXRi for Sale'
#  'DFSK Glory 580  2019 1.5 CVT for Sale'
#  'Suzuki Wagon R  2015 VXL for Sale'
#  'Honda Civic Reborn 2011 VTi 1.8 i-VTEC for Sale'
#  'Toyota Corolla  2005 XLi for Sale' 'Nissan Note  2018 1.2E for Sale'
#  'Honda Vezel  2019 Hybrid Z Honda Sensing  for ...'
#  'KIA Sportage  2020  for Sale'
#  'Honda Vezel  2021 Hybrid Z Honda Sensing  for ...'
#  'Toyota Fortuner  2017 2.7 VVTi for Sale'
#  'Toyota Prado  2012 TX L Package 2.7 for Sale'
#  'Suzuki Alto  2013 ECO-L for Sale' 'Honda Civic  1996 EXi for Sale'
#  'Toyota Passo  2012  for Sale' 'Toyota Corolla Indus 1999 XE for Sale'
#  'Suzuki Cultus  2020 Auto Gear Shift for Sale'
#  'Toyota Prius  2007 G Touring Selection 1.5 for...'
#  'Toyota Corolla Axio  2007 Luxel 1.8 for Sale'
#  'Honda City  2019 1.5 i-VTEC Prosmatec for Sale'
#  'Changan Oshan X7  2022 FutureSense for Sale'
#  'Suzuki Liana  2007 LXi (CNG) for Sale' 'Daihatsu Mira  2015 L for Sale'
#  'Suzuki FX  1988 GA for Sale' 'Lexus CT200h  2019  for Sale'
#  'Suzuki Mehran  2017 VX Euro II Limited Edition...'
#  'Toyota Crown  2018 Athlete for Sale'
#  'Toyota Hilux  2014 Vigo Champ V for Sale'
#  'Honda Vezel  2021 e-HEV X for Sale' 'Toyota C-HR  2017 S for Sale'
#  'Mitsubishi Lancer  2006  for Sale'
#  'Toyota Corolla  2004 SE Saloon for Sale'
#  'Honda City  2018 1.3 i-VTEC for Sale' 'Toyota Passo  2017 X for Sale'
#  'Suzuki Wagon R  2021 Hybrid FZ for Sale'
#  'Toyota Passo  2010 G 1.0 for Sale'
#  'Toyota Corolla  2020 XLi VVTi for Sale'
#  'Suzuki Baleno  2000 GLi P for Sale'
#  'Suzuki Bolan  2013 VX Euro II for Sale'
#  'Suzuki Margalla  1997 GL for Sale' 'Toyota Corolla Indus 1996  for Sale'
#  'Suzuki Baleno  1999 JXR for Sale'
#  'Suzuki Cultus  2003 VXL (CNG) for Sale'
#  'Mitsubishi Lancer  2005 GLX 1.6 for Sale'
#  'Toyota Corolla  2011 XLi VVTi Limited Edition ...'
#  'Toyota Land Cruiser  2013 AX G Selection for Sale'
#  'Honda City  2022 1.2L M/T for Sale' 'Suzuki Wagon R  2018 VXR for Sale'
#  'Toyota Land Cruiser 80 Series 1996 VX Limited ...'
#  'Toyota Vitz  2018  for Sale' 'Toyota Corolla Fielder  2018 X for Sale'
#  'Toyota Rav4  2002 X for Sale' 'Suzuki Wagon R  2018 Hybrid FZ for Sale'
#  'Toyota Corolla  1994 XE for Sale'
#  'Daihatsu Move  2014 Custom RS for Sale'
#  'Suzuki Cultus  2008 VXRi for Sale' 'Suzuki Wagon R  2016 VXL for Sale'
#  'Toyota Vitz  2010 F 1.0 for Sale' 'Suzuki Margalla  1998 GL for Sale'
#  'Suzuki Cultus  2020 VXL for Sale'
#  'Honda Civic Rebirth 2015 VTi Oriel Prosmatec 1...'
#  'Toyota Corolla  2020 Altis Grande X CVT-i 1.8 ...'
#  'Honda City  2015 Aspire 1.3 i-VTEC for Sale'
#  'Toyota Vitz  2017 F 1.0 for Sale' 'Suzuki FX  1982 GA for Sale'
#  'Suzuki Every  2022 PA for Sale' 'Daihatsu Cuore  2007 CL Eco for Sale'
#  'Suzuki Cultus  2018 VXR for Sale' 'Toyota Platz  2004 F 1.3 for Sale'
#  'Toyota Corolla Fielder  2018 Hybrid G  WB  for...'
#  'Suzuki Wagon R  2010 FX Limited for Sale'
#  'Suzuki Wagon R  2019 VXL for Sale'
#  'Toyota Vitz  2019 F Smile Edition 1.0 for Sale'
#  'Toyota Aqua  2012 S for Sale'
#  'Mitsubishi Pajero Mini  2010 PREMIUM SELECTION...'
#  'Mercedes Benz S Class  2001 280 SE for Sale'
#  'Nissan Otti  2011 E for Sale' 'Adam Revo  2020  for Sale'
#  'Suzuki Carry  2013 Standard for Sale' 'Toyota Tacoma  2018  for Sale'
#  'Toyota Corolla Indus 1998 XE Limited for Sale'
#  'Honda Civic Reborn 2010 VTi Prosmatec 1.8 i-VT...'
#  'Suzuki Cultus  2001 VXR (CNG) for Sale'
#  'Mercedes Benz C Class  2012 C200 for Sale'
#  'Suzuki Margalla  1996 GL for Sale'
#  'Honda N Wgn  2019 G L Package for Sale'
#  'Suzuki Swift  2016 DLX 1.3 Navigation  for Sale'
#  'Suzuki Bolan  2022 VX Euro II for Sale'
#  'Honda BR-V  2019 i-VTEC for Sale' 'Toyota Aqua  2014 S for Sale'
#  'Suzuki Cultus  2014 EURO II for Sale' 'Suzuki Wagon R  2019  for Sale'
#  'Suzuki Alto  2019 L for Sale' 'Suzuki Swift  2022 GL CVT for Sale'
#  'Audi A6 4th (C7) Generation 2016 1.8 TFSI  for...'
#  'Toyota Prado  2017 TX L Package 2.7 for Sale'
#  'Nissan Clipper  2020 G Aero Version for Sale'
#  'Suzuki Margalla  1997 GL Plus for Sale'
#  'Suzuki Mehran  2017 VXR Euro II for Sale'
#  'Mitsubishi Pajero Mini  1996 Limited for Sale'
#  'Daihatsu Cuore  2000 CL for Sale'
#  'Toyota Vitz  2014 F Limited 1.0 for Sale'
#  'Daihatsu Mira  2020 L SA for Sale'
#  'Honda Civic Rebirth 2015 VTi 1.8 i-VTEC for Sale'
#  'Toyota Prius  2011 S LED Edition 1.8 for Sale'
#  'Suzuki Khyber  1996 GA for Sale' 'Suzuki Bolan  1992 VX for Sale'
#  'Toyota Corolla  2005 Altis 1.8 for Sale'
#  'Suzuki Liana  2011 RXi for Sale'
#  'Toyota Land Cruiser 100 Series 2002  for Sale'
#  'Nissan Safari  2000  for Sale' 'Mitsubishi Pajero  2008  for Sale'
#  'Toyota Crown  2004  for Sale'
#  'Toyota Corolla  2008 GLi 1.3 VVTi for Sale'
#  'Honda City  2014 Aspire Prosmatec 1.5 i-VTEC f...'
#  'Toyota Prado 120 Series 2006 TZ 4.0 for Sale'
#  'Toyota Corolla 9th Generation 2006 Altis 1.8 f...'
#  'Nissan Clipper  2018 E Four Special Pack for Sale'
#  'Toyota Corolla  2012 Altis Cruisetronic 1.6 fo...'
#  'Toyota Vitz  2007 RS 1.3 for Sale' 'Suzuki Alto  2016  for Sale'
#  'Suzuki Alto  2007 VXR for Sale' 'Toyota Prius  2008 EX 1.5 for Sale'
#  'Suzuki Mehran  2014 VX Euro II for Sale'
#  'Suzuki Every Wagon  2014 PZ Turbo Special for ...'
#  'Suzuki Cultus  2018 VXL for Sale'
#  'Toyota Prado 120 Series 2009 TZ G 4.0 for Sale'
#  'Daihatsu Charade  1986 CL for Sale' 'MG Other  2021  for Sale'
#  'Honda Civic Hybrid  2006 MXST for Sale' 'Toyota Aqua  2019 S for Sale'
#  'Honda Civic  2021 1.8 i-VTEC CVT for Sale'
#  'Toyota Mark X  2005 250G S Package for Sale'
#  'Toyota Prado  2013 TX 2.7 for Sale'
#  'Toyota Land Cruiser 100 Series 2006 VX 4.2D fo...'
#  'Toyota Corolla  2021 Altis Grande X CVT-i 1.8 ...'
#  'Suzuki Jimny  2016  for Sale'
#  'Mitsubishi Pajero Mini  2011 Limited for Sale'
#  'Toyota Vitz  2016  for Sale' 'Toyota Corolla  2012  for Sale'
#  'Toyota Fortuner  2021 2.7 VVTi for Sale'
#  'Toyota Prado 120 Series 2007 TX Limited 2.7 fo...'
#  'Suzuki Alto  2001 VXR (CNG) for Sale' 'Toyota Raize  2021 Z for Sale'
#  'Suzuki Mehran  1991 VX for Sale'
#  'Toyota Corolla 9th Generation 2006 GLi 1.3 for...'
#  'Daihatsu Move  2014 Custom G for Sale'
#  'Toyota Corolla  2013 GLi Automatic Limited Edi...'
#  'Daihatsu Cuore  2009 CX Ecomatic for Sale'
#  'Honda Civic  2004 VTi Oriel UG Prosmatec 1.6 f...'
#  'Honda Civic  2006 VTi Prosmatec 1.6 for Sale'
#  'Chevrolet Optra  2005 1.6 Automatic for Sale'
#  'Audi A5  2019 40 TFSI quattro S tronic for Sale'
#  'Honda N Wgn  2016 Custom G L Package for Sale'
#  'Hyundai Santro  2005 Club GV for Sale'
#  'Daihatsu Hijet  2009 Special for Sale'
#  'Suzuki Bolan  2018 VX Euro II for Sale'
#  'Suzuki Cultus  2022 VXL for Sale' 'Suzuki Mehran  2010  for Sale'
#  'Toyota Corolla Axio  2015 Hybrid 1.5 for Sale'
#  'Audi A5  2014 1.8 TFSI for Sale' 'Nissan Kix  2020  for Sale'
#  'Toyota Hilux  2012 Vigo G for Sale'
#  'Daihatsu Cuore  2002 CL Eco for Sale'
#  'Honda City  2015 1.3 i-VTEC for Sale' 'Suzuki Wagon R  2016 FA for Sale'
#  'Toyota Land Cruiser  2018 ZX for Sale'
#  'Toyota Land Cruiser  2018 AX G Selection for Sale'
#  'Toyota Prado  2018 TX 2.7 for Sale'
#  'Toyota Land Cruiser  2016 AX G Selection for Sale'
#  'Toyota Mark X  2005 300G Premium for Sale'
#  'Toyota Land Cruiser  2010 AX for Sale' 'Suzuki Every  2016 GA for Sale'
#  'Toyota Corolla  1986 SE Saloon for Sale'
#  'Toyota Corolla  2015 Altis 1.8 for Sale'
#  'Mitsubishi Pajero Mini  1995 Limited for Sale'
#  'FAW V2  2018 VCT-i for Sale' 'Toyota Corolla Fielder  2016 X for Sale'
#  'Toyota Corolla Fielder  2015 Hybrid G  WB  for...'
#  'Suzuki Alto  2019 VXR for Sale'
#  'Toyota Corolla  2016 Altis Automatic 1.6 for Sale']

# %%
print(df["Fuel"].unique())
# Out:
# ['Electric' 'Petrol' 'Hybrid' 'Diesel' 'CNG']

# %%
print(df["Engine"].unique())
# Out:
# ['95.0 kWh' '3500 cc' '1800 cc' '1500 cc' '1000 cc' '2000 cc' '3799 cc'
#  '660 cc' '1300 cc' '1400 cc' '1600 cc' '2500 cc' '0.0 kWh' '2800 cc'
#  '3400 cc' '800 cc' '4000 cc' '4600 cc' '100 cc' '2700 cc' '3000 cc'
#  '5663 cc' '1200 cc' '4100 cc' '4200 cc' '4663 cc' '6400 cc' '2400 cc'
#  '2100 cc' '4700 cc' '108 cc' '230.0 kWh' '600 cc' '60.0 kWh' '4500 cc'
#  '6000 cc' '1198 cc' '10000 cc' '3200 cc' '5700 cc' '1100 cc']

# %%
print(df["Transmission_type"].unique())
# Out:
# ['Automatic' 'Manual']

# %%
print(df["Location"].unique())
# Out:
# ['Lahore' 'Khanewal' 'Islamabad' 'Karachi' 'Peshawar' 'Faisalabad'
#  'Hyderabad' 'Nowshera' 'Rawalpindi' 'Gujranwala' 'Multan' 'Sargodha'
#  'Wah cantt' 'Karak' 'Mandi bahauddin' 'Bhera' 'Swabi' 'Sialkot'
#  'Jaranwala' 'Kharian' 'D.G.Khan' 'Okara' 'Charsadda' 'Quetta'
#  'Abbottabad' 'Hafizabad' 'Mirpur A.K.' 'Bahawalpur' 'Rahim Yar Khan'
#  'Jhelum' 'Moro' 'Chakwal' 'Sukkur' 'Sara-E-Alamgir' 'Pano Aqil'
#  'Kot addu' 'Gujrat' 'Mardan' 'Sahiwal' 'Dargai' 'Quaid Abad' 'Larkana'
#  'Burewala' 'Gujar Khan' 'Sheikhupura' 'Nowshera cantt' 'Mansehra'
#  'Chishtian' 'Liaqat Pur' 'Nankana sahib' 'Pir mahal' 'Jhang'
#  'Muzaffar Gargh' 'Dina' 'Kamoke' 'Mandra' 'Taunsa sharif' 'Taxila'
#  'Lala musa' 'Mangla' 'Fort Abbass' 'Akora khattak' 'Kamra' 'Bahawalnagar'
#  'Toba Tek Singh' 'Layyah']

# %%
print(df["Price"].unique())
# Out:
# ['PKR 2.65 crore' 'PKR 2.32 crore' 'PKR 45.5 lacs' 'PKR 52.5 lacs'
#  'PKR 15.95 lacs' 'PKR 12.9 lacs' 'PKR 2 crore' 'PKR 72 lacs'
#  'PKR 50 lacs' 'PKR 31 lacs' 'PKR 60.25 lacs' 'PKR 33.49 lacs'
#  'PKR 13.4 lacs' 'PKR 20.3 lacs' 'PKR 8.5 lacs' 'PKR 11.9 lacs'
#  'PKR 46.3 lacs' 'PKR 52 lacs' 'PKR 17.5 lacs' 'PKR 4.2 lacs'
#  'PKR 36.9 lacs' 'PKR 32.5 lacs' 'PKR 18 lacs' 'PKR 36 lacs'
#  'PKR 1.55 crore' 'PKR 25.9 lacs' 'PKR 14.5 lacs' 'PKR 30.75 lacs'
#  'PKR 31.5 lacs' 'PKR 29.75 lacs' 'PKR 34 lacs' 'PKR 83 lacs'
#  'PKR 32.65 lacs' 'PKR 75 lacs' 'PKR 47 lacs' 'PKR 25.25 lacs'
#  'PKR 9 lacs' 'PKR 24.5 lacs' 'PKR 45.25 lacs' 'PKR 29 lacs'
#  'PKR 36.2 lacs' 'PKR 32 lacs' 'PKR 28 lacs' 'PKR 6 lacs' 'PKR 31.25 lacs'
#  'PKR 12.65 lacs' 'PKR 18.9 lacs' 'PKR 46.5 lacs' 'PKR 60 lacs'
#  'PKR 16.65 lacs' 'PKR 17.8 lacs' 'PKR 7.85 lacs' 'PKR 40 lacs'
#  'PKR 4.95 lacs' 'PKR 25.88 lacs' 'PKR 9.8 lacs' 'PKR 12.6 lacs'
#  'PKR 5.55 lacs' 'PKR 8.7 lacs' 'PKR 8 lacs' 'PKR 74 lacs' 'PKR 98 lacs'
#  'PKR 20.85 lacs' 'PKR 58 lacs' 'PKR 77 lacs' 'PKR 3 crore'
#  'PKR 27.5 lacs' 'PKR 56 lacs' 'PKR 16 lacs' 'PKR 48 lacs'
#  'PKR 2.45 crore' 'PKR 32.25 lacs' 'PKR 28.2 lacs' 'PKR 26.5 lacs'
#  'PKR 16.5 lacs' 'PKR 9.9 lacs' 'PKR 5 lacs' 'PKR 12.1 lacs'
#  'PKR 7.65 lacs' 'PKR 10.5 lacs' 'PKR 2.4 lacs' 'PKR 14.55 lacs'
#  'PKR 22.7 lacs' 'PKR 35 lacs' 'PKR 14.75 lacs' 'PKR 11.6 lacs'
#  'PKR 1.21 crore' 'PKR 17 lacs' 'PKR 12.8 lacs' 'PKR 10.2 lacs'
#  'PKR 17.15 lacs' 'PKR 1.25 crore' 'Call' 'PKR 84 lacs' 'PKR 20.7 lacs'
#  'PKR 29.25 lacs' 'PKR 40.5 lacs' 'PKR 3.7 crore' 'PKR 95 lacs'
#  'PKR 1.32 crore' 'PKR 85 lacs' 'PKR 63.75 lacs' 'PKR 13.7 lacs'
#  'PKR 22.95 lacs' 'PKR 30 lacs' 'PKR 2.9 lacs' 'PKR 1.05 crore'
#  'PKR 22.5 lacs' 'PKR 43 lacs' 'PKR 19.25 lacs' 'PKR 2.05 crore'
#  'PKR 28.8 lacs' 'PKR 23.5 lacs' 'PKR 21 lacs' 'PKR 57 lacs'
#  'PKR 22.45 lacs' 'PKR 18.15 lacs' 'PKR 25 lacs' 'PKR 22.75 lacs'
#  'PKR 42 lacs' 'PKR 1.01 crore' 'PKR 5.26 crore' 'PKR 2.24 crore'
#  'PKR 33.75 lacs' 'PKR 22 lacs' 'PKR 37.95 lacs' 'PKR 37.5 lacs'
#  'PKR 1.96 crore' 'PKR 15.9 lacs' 'PKR 62.5 lacs' 'PKR 39.95 lacs'
#  'PKR 39.5 lacs' 'PKR 36.75 lacs' 'PKR 93 lacs' 'PKR 1.65 crore'
#  'PKR 6.75 lacs' 'PKR 53.8 lacs' 'PKR 36.25 lacs' 'PKR 18.65 lacs'
#  'PKR 9.65 lacs' 'PKR 23 lacs' 'PKR 37 lacs' 'PKR 4.9 crore'
#  'PKR 22.55 lacs' 'PKR 19.85 lacs' 'PKR 36.3 lacs' 'PKR 33.7 lacs'
#  'PKR 9.75 lacs' 'PKR 14.9 lacs' 'PKR 9.25 lacs' 'PKR 27.1 lacs'
#  'PKR 38.9 lacs' 'PKR 24.9 lacs' 'PKR 1.41 lacs' 'PKR 19 lacs'
#  'PKR 18.2 lacs' 'PKR 29.5 lacs' 'PKR 1.2 crore' 'PKR 2.75 lacs'
#  'PKR 6.9 lacs' 'PKR 86 lacs' 'PKR 54.75 lacs' 'PKR 18.75 lacs'
#  'PKR 41.5 lacs' 'PKR 23.25 lacs' 'PKR 12.25 lacs' 'PKR 2.15 crore'
#  'PKR 80 lacs' 'PKR 20.65 lacs' 'PKR 4.98 lacs' 'PKR 5.5 lacs'
#  'PKR 33.2 lacs' 'PKR 16.8 lacs' 'PKR 10.1 lacs' 'PKR 23.35 lacs'
#  'PKR 16.3 lacs' 'PKR 2.5 lacs' 'PKR 7.2 lacs' 'PKR 13.75 lacs'
#  'PKR 38.35 lacs' 'PKR 26 lacs' 'PKR 7.7 lacs' 'PKR 13 lacs'
#  'PKR 59.5 lacs' 'PKR 17.7 lacs' 'PKR 20.9 lacs' 'PKR 29.7 lacs'
#  'PKR 1.4 crore' 'PKR 25.5 lacs' 'PKR 64 lacs' 'PKR 34.75 lacs'
#  'PKR 12.95 lacs' 'PKR 9.85 lacs' 'PKR 45 lacs' 'PKR 44.8 lacs'
#  'PKR 6.3 lacs' 'PKR 2.35 lacs' 'PKR 5.8 lacs' 'PKR 65 lacs'
#  'PKR 5.3 lacs' 'PKR 39.6 lacs' 'PKR 10 lacs' 'PKR 8.95 lacs'
#  'PKR 18.5 lacs' 'PKR 22.25 lacs' 'PKR 1.15 crore' 'PKR 28.5 lacs'
#  'PKR 21.75 lacs' 'PKR 50.5 lacs' 'PKR 9.5 lacs' 'PKR 8.2 lacs'
#  'PKR 38 lacs' 'PKR 62 lacs' 'PKR 9.35 lacs' 'PKR 68.5 lacs'
#  'PKR 32.75 lacs' 'PKR 2.02 crore' 'PKR 55 lacs' 'PKR 12.75 lacs'
#  'PKR 1 crore' 'PKR 63 lacs' 'PKR 1.18 crore' 'PKR 17.9 lacs'
#  'PKR 24.35 lacs' 'PKR 4.9 lacs' 'PKR 10.7 lacs' 'PKR 7.6 lacs'
#  'PKR 13.95 lacs' 'PKR 35.5 lacs' 'PKR 19.8 lacs' 'PKR 28.6 lacs'
#  'PKR 83.25 lacs' 'PKR 22.4 lacs' 'PKR 82 lacs' 'PKR 58.75 lacs'
#  'PKR 59.8 lacs' 'PKR 51.85 lacs' 'PKR 23.85 lacs' 'PKR 27.85 lacs'
#  'PKR 19.15 lacs' 'PKR 6.95 lacs' 'PKR 19.75 lacs' 'PKR 28.15 lacs'
#  'PKR 15.25 lacs' 'PKR 34.5 lacs' 'PKR 10.54 lacs' 'PKR 23.7 lacs'
#  'PKR 2.42 crore' 'PKR 13.5 lacs' 'PKR 14 lacs' 'PKR 1.73 crore'
#  'PKR 53.75 lacs' 'PKR 76 lacs' 'PKR 24.2 lacs' 'PKR 27 lacs'
#  'PKR 20.5 lacs' 'PKR 36.5 lacs' 'PKR 28.75 lacs' 'PKR 15 lacs'
#  'PKR 58.9 lacs' 'PKR 1.25 lacs' 'PKR 31.9 lacs' 'PKR 32.9 lacs'
#  'PKR 29.6 lacs' 'PKR 1.19 crore' 'PKR 23.75 lacs' 'PKR 27.75 lacs'
#  'PKR 26.45 lacs' 'PKR 42.5 lacs' 'PKR 77.7 lacs' 'PKR 53.5 lacs'
#  'PKR 3.5 crore' 'PKR 13.2 lacs' 'PKR 19.5 lacs' 'PKR 6.2 lacs'
#  'PKR 15.6 lacs' 'PKR 33.65 lacs' 'PKR 33.6 lacs' 'PKR 2.08 crore'
#  'PKR 28.55 lacs' 'PKR 30.25 lacs' 'PKR 41 lacs' 'PKR 32.35 lacs'
#  'PKR 43.9 lacs' 'PKR 3.85 crore' 'PKR 12.4 lacs' 'PKR 24.75 lacs'
#  'PKR 2.7 lacs' 'PKR 9.2 lacs' 'PKR 20 lacs' 'PKR 33 lacs' 'PKR 9.3 lacs'
#  'PKR 41.75 lacs' 'PKR 38.95 lacs' 'PKR 21.5 lacs' 'PKR 3.35 crore'
#  'PKR 13.65 lacs' 'PKR 33.5 lacs' 'PKR 61.5 lacs' 'PKR 6.25 lacs'
#  'PKR 14.3 lacs' 'PKR 33.8 lacs' 'PKR 25.8 lacs' 'PKR 11.95 lacs'
#  'PKR 16.4 lacs' 'PKR 28.85 lacs' 'PKR 11.8 lacs' 'PKR 3.2 lacs'
#  'PKR 7 lacs' 'PKR 49.25 lacs' 'PKR 55.5 lacs' 'PKR 17.2 lacs'
#  'PKR 16.9 lacs' 'PKR 1.97 crore' 'PKR 25.85 lacs' 'PKR 15.7 lacs'
#  'PKR 8.65 lacs' 'PKR 10.75 lacs' 'PKR 59 lacs' 'PKR 90 lacs'
#  'PKR 11.5 lacs' 'PKR 72.5 lacs' 'PKR 41.25 lacs' 'PKR 49.85 lacs'
#  'PKR 39.3 lacs' 'PKR 1.68 crore' 'PKR 1.7 crore' 'PKR 82.5 lacs'
#  'PKR 67 lacs' 'PKR 1.17 crore' 'PKR 83.5 lacs' 'PKR 22.9 lacs'
#  'PKR 15.5 lacs' 'PKR 11 lacs' 'PKR 51.5 lacs' 'PKR 24 lacs' 'PKR 46 lacs'
#  'PKR 7.8 lacs' 'PKR 27.9 lacs' 'PKR 31.75 lacs' 'PKR 18.7 lacs'
#  'PKR 47.6 lacs' 'PKR 48.5 lacs' 'PKR 51.95 lacs' 'PKR 49.1 lacs'
#  'PKR 40.75 lacs' 'PKR 26.75 lacs' 'PKR 30.5 lacs' 'PKR 64.5 lacs'
#  'PKR 24.4 lacs' 'PKR 39 lacs' 'PKR 32.7 lacs' 'PKR 7.5 lacs'
#  'PKR 38.5 lacs' 'PKR 30.85 lacs' 'PKR 88 lacs' 'PKR 59.75 lacs'
#  'PKR 1.95 crore' 'PKR 44.5 lacs' 'PKR 61.25 lacs' 'PKR 91 lacs'
#  'PKR 74.5 lacs' 'PKR 12.45 lacs' 'PKR 34.35 lacs' 'PKR 17.85 lacs'
#  'PKR 14.7 lacs' 'PKR 6.85 lacs' 'PKR 25.95 lacs' 'PKR 34.28 lacs'
#  'PKR 16.2 lacs' 'PKR 37.25 lacs' 'PKR 1.9 crore' 'PKR 2.77 crore'
#  'PKR 2.7 crore' 'PKR 55.95 lacs' 'PKR 75.9 lacs' 'PKR 49.5 lacs'
#  'PKR 32.6 lacs' 'PKR 15.8 lacs' 'PKR 12.5 lacs' 'PKR 12.16 lacs'
#  'PKR 85.5 lacs' 'PKR 66 lacs' 'PKR 21.7 lacs' 'PKR 6.65 lacs'
#  'PKR 27.3 lacs' 'PKR 1.02 crore' 'PKR 42.75 lacs' 'PKR 43.5 lacs'
#  'PKR 51 lacs' 'PKR 56.5 lacs' 'PKR 88.5 lacs' 'PKR 83.85 lacs'
#  'PKR 1.31 crore' 'PKR 13.9 lacs' 'PKR 9.7 lacs' 'PKR 1.75 crore'
#  'PKR 70 lacs' 'PKR 37.8 lacs' 'PKR 92.5 lacs' 'PKR 16.85 lacs'
#  'PKR 2.3 lacs' 'PKR 61 lacs' 'PKR 1.87 crore' 'PKR 60.5 lacs'
#  'PKR 16.35 lacs' 'PKR 19.7 lacs' 'PKR 12.3 lacs' 'PKR 6.68 lacs'
#  'PKR 17.65 lacs' 'PKR 4.5 lacs' 'PKR 12 lacs' 'PKR 18.1 lacs'
#  'PKR 2.4 crore' 'PKR 16.7 lacs' 'PKR 28.3 lacs' 'PKR 25.75 lacs'
#  'PKR 15.75 lacs' 'PKR 6.6 lacs' 'PKR 23.45 lacs' 'PKR 7.99 lacs'
#  'PKR 44 lacs' 'PKR 3.75 lacs' 'PKR 7.25 lacs' 'PKR 31.95 lacs'
#  'PKR 23.95 lacs' 'PKR 16.45 lacs' 'PKR 14.2 lacs' 'PKR 79.9 lacs'
#  'PKR 34.65 lacs' 'PKR 21.9 lacs' 'PKR 1.78 crore' 'PKR 26.95 lacs'
#  'PKR 31.85 lacs' 'PKR 31.55 lacs' 'PKR 2.35 crore' 'PKR 5.25 lacs'
#  'PKR 6.1 lacs' 'PKR 17.45 lacs' 'PKR 3.6 lacs' 'PKR 50.25 lacs'
#  'PKR 35.45 lacs' 'PKR 13.8 lacs' 'PKR 6.35 lacs' 'PKR 14.25 lacs'
#  'PKR 8.75 lacs' 'PKR 1.38 crore' 'PKR 47.75 lacs' 'PKR 33.25 lacs'
#  'PKR 51.75 lacs' 'PKR 83.1 lacs' 'PKR 26.85 lacs' 'PKR 92 lacs'
#  'PKR 47.5 lacs' 'PKR 1.06 crore' 'PKR 17.25 lacs' 'PKR 2.6 lacs'
#  'PKR 69.9 lacs' 'PKR 14.8 lacs' 'PKR 3.37 crore' 'PKR 1.35 crore'
#  'PKR 5.2 crore' 'PKR 7.3 lacs' 'PKR 12.2 lacs' 'PKR 27.55 lacs'
#  'PKR 21.25 lacs' 'PKR 5.15 crore' 'PKR 3.55 crore' 'PKR 4.1 crore'
#  'PKR 2.12 crore' 'PKR 2.85 crore' 'PKR 1.8 crore' 'PKR 14.65 lacs'
#  'PKR 26.65 lacs' 'PKR 3.65 lacs' 'PKR 15.3 lacs' 'PKR 24.25 lacs'
#  'PKR 8.25 lacs' 'PKR 26.9 lacs' 'PKR 2.2 lacs' 'PKR 3.6 crore']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

df['Title']=le.fit_transform(df["Title"])
df['Location']=le.fit_transform(df["Location"])

# %%
df["Transmission_type"].replace(['Automatic','Manual'],[0,1],inplace=True)
# Out:
# /tmp/ipykernel_9932/2863931977.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Transmission_type"].replace(['Automatic','Manual'],[0,1],inplace=True)
# /tmp/ipykernel_9932/2863931977.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Transmission_type"].replace(['Automatic','Manual'],[0,1],inplace=True)

# %%
df["Fuel"].replace(['Electric','Petrol','Hybrid','Diesel','CNG'],[0,1,2,3,4],inplace=True)
# Out:
# /tmp/ipykernel_9932/1732307274.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Fuel"].replace(['Electric','Petrol','Hybrid','Diesel','CNG'],[0,1,2,3,4],inplace=True)
# /tmp/ipykernel_9932/1732307274.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Fuel"].replace(['Electric','Petrol','Hybrid','Diesel','CNG'],[0,1,2,3,4],inplace=True)

# %%
# split engine into two columns
df[['engine_value', 'engine_unit']] = df['Engine'].str.split(' ', expand=True)

# convert engine_value to numeric
df['engine_value'] = pd.to_numeric(df['engine_value'], errors='coerce')

# check result
print(df[['Engine', 'engine_value', 'engine_unit']].head())
# Out:
#      Engine  engine_value engine_unit
# 0  95.0 kWh          95.0         kWh
# 1  95.0 kWh          95.0         kWh
# 2   3500 cc        3500.0          cc
# 3  95.0 kWh          95.0         kWh
# 4   3500 cc        3500.0          cc

# %%
df
# Out:
#        Unnamed: 0  Title  Model  Fuel    Engine  Transmission_type  Location  \
# 0               0     10   2021     0  95.0 kWh                  0        30
# 1               1     10   2021     0  95.0 kWh                  0        30
# 2               2    194   2017     1   3500 cc                  0        30
# 3               3     10   2021     0  95.0 kWh                  0        30
# 4               4    194   2017     1   3500 cc                  0        30
# ...           ...    ...    ...   ...       ...                ...       ...
# 20817       20817    576   2017     1   4600 cc                  0        30
# 20818       20818     88   2018     1   1300 cc                  1        27
# 20819       20819    397   2022     1   1200 cc                  0        30
# 20820       20820    239   2013     1    660 cc                  0        30
# 20821       20821    482   2016     1   1600 cc                  0        25
#
#                 Price  engine_value engine_unit
# 0      PKR 2.65 crore          95.0         kWh
# 1      PKR 2.65 crore          95.0         kWh
# 2      PKR 2.32 crore        3500.0          cc
# 3      PKR 2.65 crore          95.0         kWh
# 4      PKR 2.32 crore        3500.0          cc
# ...               ...           ...         ...
# 20817   PKR 3.6 crore        4600.0          cc
# 20818  PKR 25.25 lacs        1300.0          cc
# 20819     PKR 35 lacs        1200.0          cc
# 20820  PKR 15.25 lacs         660.0          cc
# 20821   PKR 29.5 lacs        1600.0          cc
#
# [20822 rows x 10 columns]

# %%
df.drop("Engine",inplace=True,axis=1)

# %%
print(df["engine_unit"].unique())
# Out:
# ['kWh' 'cc']

# %%
df["engine_unit"].replace(['kWh','cc'],[0,1],inplace=True)
# Out:
# /tmp/ipykernel_9932/71426669.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["engine_unit"].replace(['kWh','cc'],[0,1],inplace=True)
# /tmp/ipykernel_9932/71426669.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["engine_unit"].replace(['kWh','cc'],[0,1],inplace=True)

# %%
import numpy as np

def convert_price(x):
    if x == 'Call':
        return np.nan

    x = x.replace('PKR', '').strip()

    if 'crore' in x:
        return float(x.replace('crore', '').strip()) * 10000000
    elif 'lacs' in x:
        return float(x.replace('lacs', '').strip()) * 100000
    else:
        return np.nan

df['price_pkr'] = df['Price'].apply(convert_price)

# %%
df.drop("Price",inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20822 entries, 0 to 20821
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         20822 non-null  int64
#  1   Title              20822 non-null  int64
#  2   Model              20822 non-null  int64
#  3   Fuel               20822 non-null  int64
#  4   Transmission_type  20822 non-null  int64
#  5   Location           20822 non-null  int64
#  6   engine_value       20822 non-null  float64
#  7   engine_unit        20822 non-null  int64
#  8   price_pkr          19843 non-null  float64
# dtypes: float64(2), int64(7)
# memory usage: 1.4 MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Title                  0
# Model                  0
# Fuel                   0
# Transmission_type      0
# Location               0
# engine_value           0
# engine_unit            0
# price_pkr            979
# dtype: int64

# %%
df['price_pkr'] = df['price_pkr'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Title                0
# Model                0
# Fuel                 0
# Transmission_type    0
# Location             0
# engine_value         0
# engine_unit          0
# price_pkr            0
# dtype: int64

# %% [markdown]
# #  After converting check correlation:

# %%
corr_matrix=df.corr()
sns.heatmap(corr_matrix,annot=True,fmt="0.01f",cmap="coolwarm")
plt.title("Correlation matrix")
plt.show()

# %%
status_corr=df.corr()["price_pkr"]
status_corr=status_corr.drop("price_pkr")
sns.heatmap(status_corr.to_frame(), annot=True,fmt=' .2f',cmap='coolwarm',cbar=True, annot_kws={'size':10})
plt.title('correlation between loan_status and other features')
plt.show()

# %%
df.drop(["Unnamed: 0","Fuel","engine_unit"],axis=1,inplace=True)

# %% [markdown]
# # Outlier cheking and removing

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
def remove_outliers_iqr(df,exclude_column):
  for col in df.columns:
    if col==exclude_column:
       continue
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)
    IQR =Q3-Q1
    lower_bound = Q1 -1.5 *IQR
    upper_bound = Q3 +1.5 *IQR
    df=df[(df[col]>= lower_bound)&(df[col]<=upper_bound)]
  return df

df_cleaned= remove_outliers_iqr(df,exclude_column='price')
df=df_cleaned

# %%
df.shape
# Out:
# (11181, 6)

# %% [markdown]
# # Data Scaling

# %%
print(df.columns)
# Out:
# Index(['Title', 'Model', 'Transmission_type', 'Location', 'engine_value',
#        'price_pkr'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
features =['Title', 'Model', 'Transmission_type', 'Location', 'engine_value']
scaler=MinMaxScaler()
scaled_data=scaler.fit_transform(df[features])
scaled_df = pd.DataFrame(scaled_data, columns=features)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
import pandas as pd

x=df[['Title', 'Model', 'Transmission_type', 'Location', 'engine_value']]
y=df["price_pkr"]

x_train, x_test, y_train, y_test =train_test_split(x,y, test_size=0.25, random_state=42)

model=LinearRegression()
model.fit(x_train,y_train)

y_pred=model.predict(x_test)
accuracy = model.score(x_test,y_test)
print(f"Baseline model accuracy: {accuracy:.2f}")
# Out:
# Baseline model accuracy: 0.27

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import accuracy_score
import pandas as pd

x=df[['Title', 'Model', 'Transmission_type', 'Location', 'engine_value']]
y=df["price_pkr"]

x_train, x_test, y_train, y_test =train_test_split(x,y, test_size=0.25, random_state=42)

model=SVR(kernel="poly",degree=8)
model.fit(x_train,y_train)

y_pred=model.predict(x_test)
accuracy = model.score(x_test,y_test)
print(f"Baseline model accuracy: {accuracy:.2f}")
# Out:
# Baseline model accuracy: 0.06
